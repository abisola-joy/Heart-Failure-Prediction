# %%
#import module
import EDA_ML
import tkinter as tk
from tkinter import ttk

# %%
def dataset():
    print("Displaying Dataset Summary")
    # call the dataset function from the EDA_ML module
    print()
    EDA_ML.dataset()

def missing_values():
    print("Checking for Missing Values")
    # call the checking_missing_values function from the EDA_ML module
    print()
    print(EDA_ML.checking_missing_values())

def mean():
    print("Displaying Mean")
    # call the measures_of_location function from the EDA_ML module
    print()
    EDA_ML.measures_of_location('mean')

def median():
    print("Displaying Median")
    # call the measures_of_location function from the EDA_ML module
    print()
    EDA_ML.measures_of_location('median')

def skewness():
    print("Displaying Skewness")
    # call the measures_of_location function from the EDA_ML module 
    print()
    EDA_ML.measures_of_location('skew')

def kurtosis():
    print("Displaying Kurtosis")
    # call the measures_of_location function from the EDA_ML module
    print()
    EDA_ML.measures_of_location('kurt')

def standard_deviation():
    print("Displaying Standard Deviation")
    # call the measures_of_spread function from the EDA_ML module 
    print()
    EDA_ML.measures_of_spread('std')

def range_spread():
    print("Displaying Range")
    # call the measures_of_spread function from the EDA_ML module 
    print()
    EDA_ML.measures_of_spread('range')

def variance():
    print("Displaying Variance")
    # call the measures_of_spread function from the EDA_ML module 
    print()
    EDA_ML.measures_of_spread('var')

def histogram():
    print("Displaying Histogram")
    # call the plots function from the EDA_ML module
    print()
    EDA_ML.plots('hist')

def barplot():
    print("Displaying Bar Plot")
    # call the plots function from the EDA_ML module
    print()
    EDA_ML.plots('bar')

def heatmap():
    print("Displaying Correlation Heatmap")
    # call the plots function from the EDA_ML module 
    print()
    EDA_ML.plots('corr')

def boxplot():
    print("Displaying Boxplot")
    # call the plots function from the EDA_ML module 
    print()
    EDA_ML.plots('box')

def gnb():
    print("Performing Classification I")
    #Gaussian Naive Bayes
    print()
    EDA_ML.classI('gnb')
    print()
    
def lr():
    print("Performing Classification I")
    # Logistic Regression
    print()
    EDA_ML.classI('lr')
    print()
    
def knn():
    print("Performing Classification I")
    # Nearest Neighbor Model   
    print()
    EDA_ML.classI('knn') 
    print()
    
def rfc():
    print("Performing Classification I")
    # Random Forest Classifier
    print()
    EDA_ML.classI('rfc')
    print()

def svc():
    print("Performing Classification I")
    # Support Vector Machine 
    print()
    EDA_ML.classI('svm')  
    print()

def mpnn():
    print("Performing Classification I")
    # Multi-Layer Perceptron Neural Networks 
    print()
    EDA_ML.classI('mpnn') 
    print()
    
def imbalance():
    print("Performing Classification II")
    print("Class Imbalance Check")
    #class imbalance
    print()
    EDA_ML.class_imb()
    print()

def smote():
    print("Performing Classification II")
    print("Class Imbalance Check - SMOTE")
    #class imbalance - smote
    print()
    EDA_ML.smote()
    print()

def adasyn():
    print("Performing Classification II")
    print("Class Imbalance Check - SMOTE")
    #class imbalance - adasyn
    print()
    EDA_ML.adasyn()
    print()
    
def gnb_s():
    print("Performing Classification II")
    #Gaussian Naive Bayes
    print()
    EDA_ML.classII_S('gnb')
    print()
    
def lr_s():
    print("Performing Classification II")
    # Logistic Regression
    print()
    EDA_ML.classII_S('lr')
    print()
    
def knn_s():
    print("Performing Classification II")
    # Nearest Neighbor Model   
    print()
    EDA_ML.classII_S('knn') 
    print()
    
def rfc_s():
    print("Performing Classification II")
    # Random Forest Classifier
    print()
    EDA_ML.classII_S('rfc')
    print()

def svc_s():
    print("Performing Classification II")
    # Support Vector Machine 
    print()
    EDA_ML.classII_S('svm')  
    print()

def mpnn_s():
    print("Performing Classification II")
    # Multi-Layer Perceptron Neural Networks 
    print()
    EDA_ML.classII_S('mpnn') 
    print()
    
def gnb_a():
    print("Performing Classification II")
    #Gaussian Naive Bayes
    print()
    EDA_ML.classII_A('gnb')
    print()
    
def lr_a():
    print("Performing Classification II")
    # Logistic Regression
    print()
    EDA_ML.classII_A('lr')
    print()
    
def knn_a():
    print("Performing Classification II")
    # Nearest Neighbor Model   
    print()
    EDA_ML.classII_A('knn') 
    print()
    
def rfc_a():
    print("Performing Classification II")
    # Random Forest Classifier
    print()
    EDA_ML.classII_A('rfc')
    print()

def svc_a():
    print("Performing Classification II")
    # Support Vector Machine 
    print()
    EDA_ML.classII_A('svm')  
    print()

def mpnn_a():
    print("Performing Classification II")
    # Multi-Layer Perceptron Neural Networks 
    print()
    EDA_ML.classII_A('mpnn') 
    print()    
    
def m_w():
    print("Performing Feature Selection")
    #Mann-Whitney test for feature selection
    print()
    EDA_ML.feature_selection('m_w')
    print()

def chi():
    print("Performing Feature Selection")
    #Chi-square test for feature selection
    print()
    EDA_ML.feature_selection('chi')  
    print()

def rfc_fs():
    print("Performing Feature Selection")
    # Random Forest feature importance plot 
    print()
    EDA_ML.feature_selection('rfc') 
    print()        
    
def gnb_iii():
    print("Performing Classification III")
    #Gaussian Naive Bayes
    print()
    EDA_ML.classIII('gnb')
    print()
    
def lr_iii():
    print("Performing Classification III")
    # Logistic Regression
    print()
    EDA_ML.classIII('lr')
    print()
    
def knn_iii():
    print("Performing Classification III")
    # Nearest Neighbor Model   
    print()
    EDA_ML.classIII('knn') 
    print()
    
def rfc_iii():
    print("Performing Classification III")
    # Random Forest Classifier
    print()
    EDA_ML.classIII('rfc')
    print()

def svc_iii():
    print("Performing Classification III")
    # Support Vector Machine 
    print()
    EDA_ML.classIII('svc')  
    print()

def mpnn_iii():
    print("Performing Classification III")
    # Multi-Layer Perceptron Neural Networks 
    print()
    EDA_ML.classIII('mpnn') 
    print()    

def main():
    # Create the Tkinter root window
    root = tk.Tk()
    root.title("HEART FAILURE SURVIVAL PREDICTION")
    root.geometry("500x500")

    # Add a label to show the title of the analysis methods
    label = ttk.Label(root, text="CHOOSE ANALYSIS METHOD")
    label.pack(pady=10)
    
    # Add a frame and a canvas to create the scrollable list
    frame = ttk.Frame(root)
    canvas = tk.Canvas(frame, bg='#FFFFFF')
    scrollbar = tk.Scrollbar(frame, orient='vertical', command=canvas.yview)
    scroll_frame = ttk.Frame(canvas)
    scroll_frame.bind("<Configure>", lambda e: canvas.configure(scrollregion=canvas.bbox("all")))
    canvas.create_window((0, 0), window=scroll_frame, anchor='nw')
    canvas.configure(yscrollcommand=scrollbar.set)
    frame.pack()
    canvas.pack(side="left", fill="both", expand=False)
    scrollbar.pack(side="right", fill="y")

    #Explanatory Data Analysis
    #dataset summary button
    dataset_button = ttk.Button(scroll_frame, text="Dataset Summary", command=dataset)
    dataset_button.pack(pady=10)

    #missing values button
    missing_values_button = ttk.Button(scroll_frame, text="Missing Values", command=missing_values)
    missing_values_button.pack(pady=10)

    #label for measures of location
    measures_of_location_label = ttk.Label(scroll_frame, text="Measures of Location")
    measures_of_location_label.pack(pady=10)

    # mean button
    mean_button = ttk.Button(scroll_frame, text="Mean", command=mean)
    mean_button.pack(pady=10)

    #median button
    median_button = ttk.Button(scroll_frame, text="Median", command=median)
    median_button.pack(pady=10)

    #skewness button
    skewness_button = ttk.Button(scroll_frame, text="Skewness", command=skewness)
    skewness_button.pack(pady=10)

    #kurtosis button
    kurtosis_button = ttk.Button(scroll_frame, text="Kurtosis", command=kurtosis)
    kurtosis_button.pack(pady=10)

    #label for measures of spread
    measures_of_spread_label = ttk.Label(scroll_frame, text="Measures of Spread")
    measures_of_spread_label.pack(pady=10)

    #std button
    standard_deviation_button = ttk.Button(scroll_frame, text="Standard Deviation", command=standard_deviation)
    standard_deviation_button.pack(pady=10)

    #range button
    range_spread_button = ttk.Button(scroll_frame, text="Range", command=range_spread)
    range_spread_button.pack(pady=10)

    #variance button
    variance_button = ttk.Button(scroll_frame, text="Variance", command=variance)
    variance_button.pack(pady=10)

    #label for plots
    plots_label = ttk.Label(scroll_frame, text="Plots")
    plots_label.pack(pady=10)

    #histogram button
    histogram_button = ttk.Button(scroll_frame, text="Histogram", command=histogram)
    histogram_button.pack(pady=10)

    #barplot button 
    barplot_button = ttk.Button(scroll_frame, text="Bar Plot", command=barplot)
    barplot_button.pack(pady=10)

    #heatmap button 
    heatmap_button = ttk.Button(scroll_frame, text= "Heatmap", command=heatmap)
    heatmap_button.pack(pady=10)
    
    #boxplot button 
    boxplot_button = ttk.Button(scroll_frame, text= "Box Plot", command=boxplot)
    boxplot_button.pack(pady=10)
    
    #Machine learning
    #label for Classification I
    Machine_learning_label = ttk.Label(scroll_frame, text="Classification I")
    Machine_learning_label.pack(pady=10)
    
    #Gaussian Naive Bayes button
    gnb_button = ttk.Button(scroll_frame, text="Gaussian Naive Bayes", command=gnb)
    gnb_button.pack(pady=10)

    #Logistic Regression button
    lr_button = ttk.Button(scroll_frame, text="Logistic Regression", command=lr)
    lr_button.pack(pady=10)

    #Nearest Neighbor Model button
    knn_button = ttk.Button(scroll_frame, text="Nearest Neighbor Model", command=knn)
    knn_button.pack(pady=10)

    #Random Forest Classifier button
    rfc_button = ttk.Button(scroll_frame, text="Random Forest Classifier", command=rfc)
    rfc_button.pack(pady=10)

    #Support Vector Machine button
    svc_button = ttk.Button(scroll_frame, text="Support Vector Machine", command=svc)
    svc_button.pack(pady=10)
    
    #Multi-Layer Perceptron Neural Networks button
    mpnn_button = ttk.Button(scroll_frame, text="Multi-Layer Perceptron Neural Networks", command=mpnn)
    mpnn_button.pack(pady=10)
    
    #label for Classification II
    class_label = ttk.Label(scroll_frame, text="Classification II")
    class_label.pack(pady=10)
    
    #class imbalance button
    imb_button = ttk.Button(scroll_frame, text="Class Imbalance", command=imbalance)
    imb_button.pack(pady=10)

    #class imbalance smote button
    smote_button = ttk.Button(scroll_frame, text="Class Imbalance Check- SMOTE", command=smote)
    smote_button.pack(pady=10)

    #class imbalance adasyn button
    adasyn_button = ttk.Button(scroll_frame, text="Class Imbalance Check- ADASYN", command=adasyn)
    adasyn_button.pack(pady=10)
    
    #label for Classification II - class balancing
    smo_label = ttk.Label(scroll_frame, text="Classification II - Class Balancing with SMOTE")
    smo_label.pack(pady=10)
    
    #Gaussian Naive Bayes button
    gnb_s_button = ttk.Button(scroll_frame, text="Gaussian Naive Bayes", command=gnb_s)
    gnb_s_button.pack(pady=10)

    #Logistic Regression button
    lr_s_button = ttk.Button(scroll_frame, text="Logistic Regression", command=lr_s)
    lr_s_button.pack(pady=10)

    #Nearest Neighbor Model button
    knn_s_button = ttk.Button(scroll_frame, text="Nearest Neighbor Model", command=knn_s)
    knn_s_button.pack(pady=10)

    #Random Forest Classifier button
    rfc_s_button = ttk.Button(scroll_frame, text="Random Forest Classifier", command=rfc_s)
    rfc_s_button.pack(pady=10)

    #Support Vector Machine button
    svc_s_button = ttk.Button(scroll_frame, text="Support Vector Machine", command=svc_s)
    svc_s_button.pack(pady=10)
    
    #Multi-Layer Perceptron Neural Networks button
    mpnn_s_button = ttk.Button(scroll_frame, text="Multi-Layer Perceptron Neural Networks", command=mpnn_s)
    mpnn_s_button.pack(pady=10)
    
    #label for Classification II - class balancing
    ada_label = ttk.Label(scroll_frame, text="Classification II - Class Balancing with ADASYN")
    ada_label.pack(pady=10)
    
    #Gaussian Naive Bayes button
    gnb_a_button = ttk.Button(scroll_frame, text="Gaussian Naive Bayes", command=gnb_a)
    gnb_a_button.pack(pady=10)

    #Logistic Regression button
    lr_a_button = ttk.Button(scroll_frame, text="Logistic Regression", command=lr_a)
    lr_a_button.pack(pady=10)

    #Nearest Neighbor Model button
    knn_a_button = ttk.Button(scroll_frame, text="Nearest Neighbor Model", command=knn_a)
    knn_a_button.pack(pady=10)

    #Random Forest Classifier button
    rfc_a_button = ttk.Button(scroll_frame, text="Random Forest Classifier", command=rfc_a)
    rfc_a_button.pack(pady=10)

    #Support Vector Machine button
    svc_a_button = ttk.Button(scroll_frame, text="Support Vector Machine", command=svc_a)
    svc_a_button.pack(pady=10)
    
    #Multi-Layer Perceptron Neural Networks button
    mpnn_a_button = ttk.Button(scroll_frame, text="Multi-Layer Perceptron Neural Networks", command=mpnn_a)
    mpnn_a_button.pack(pady=10)
    
     #label for Classification II - class balancing
    smo_label = ttk.Label(scroll_frame, text="Feature Selection")
    smo_label.pack(pady=10)
    
    #Mann-Whitney button
    m_w_button = ttk.Button(scroll_frame, text="Mann-Whitney Test for Feature Selection", command=m_w)
    m_w_button.pack(pady=10)

    #Chi-square test button
    chi_button = ttk.Button(scroll_frame, text="Chi-square Test for Feature Selection", command=chi)
    chi_button.pack(pady=10)

    #Random Forest feature importance plot button
    rfc_fs_button = ttk.Button(scroll_frame, text="Random Forest Feature Importance Plot", command=rfc_fs)
    rfc_fs_button.pack(pady=10)
    
    #label for Classification III
    classIII_label = ttk.Label(scroll_frame, text="Classification III")
    classIII_label.pack(pady=10)
    
    #Gaussian Naive Bayes button
    gnb_iii_button = ttk.Button(scroll_frame, text="Gaussian Naive Bayes", command=gnb_iii)
    gnb_iii_button.pack(pady=10)

    #Logistic Regression button
    lr_iii_button = ttk.Button(scroll_frame, text="Logistic Regression", command=lr_iii)
    lr_a_button.pack(pady=10)

    #Nearest Neighbor Model button
    knn_iii_button = ttk.Button(scroll_frame, text="Nearest Neighbor Model", command=knn_iii)
    knn_iii_button.pack(pady=10)

    #Random Forest Classifier button
    rfc_iii_button = ttk.Button(scroll_frame, text="Random Forest Classifier", command=rfc_iii)
    rfc_iii_button.pack(pady=10)

    #Support Vector Machine button
    svc_iii_button = ttk.Button(scroll_frame, text="Support Vector Machine", command=svc_iii)
    svc_iii_button.pack(pady=10)
    
    #Multi-Layer Perceptron Neural Networks button
    mpnn_iii_button = ttk.Button(scroll_frame, text="Multi-Layer Perceptron Neural Networks", command=mpnn_iii)
    mpnn_iii_button.pack(pady=10)
    
    
    root.mainloop()

# %%
main()
# Out:
# Displaying Dataset Summary
#
# 	SUMMARY OF SOME VARIABLES IN THE DATASET
# DEATH_EVENT:
# The total survived patients are: 203
# The total dead patients are: 96
#
# SEX:
# The total female patients are: 105
# The total male patients are: 194
#
# AGE:
# Minimum: 40
# Maximum: 95
#
# CREATININE PHOSPHOKINASE:
# Minimum: 23
# Maximum: 7861
#
# EJECTION FRACTION:
# Minimum: 14
# Maximum: 80
#
# PLATELETS:
# Minimum: 25100
# Maximum: 850000
#
# SERUM CREATININE:
# Minimum: 0.5
# Maximum: 9.4
#
# SERUM SODIUM:
# Minimum: 113
# Maximum: 148
#
# TIME:
# Minimum time: 4
# Maximum time: 285
# Checking for Missing Values
#
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# ...
